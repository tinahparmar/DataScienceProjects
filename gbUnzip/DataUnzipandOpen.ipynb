# %%
import numpy as np
import pickle
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from zipfile import ZipFile
import hashlib

# %%
#This object is for unzipping files
z = ZipFile('grupo-bimbo-inventory-demand.zip')
text_files = z.infolist()

# %%
#This is the file to change if you want to a different csv
fileNameToBeReadIn="train.csv"

# %%
#Here we are creating a dataframe, called df, that pandas reads the filename declared above
df=pd.read_csv(z.open(fileNameToBeReadIn))

# %%
df.head(10)
# Out:
#    Semana  Agencia_ID  Canal_ID  Ruta_SAK  Cliente_ID  Producto_ID  \
# 0       3        1110         7      3301       15766         1212
# 1       3        1110         7      3301       15766         1216
# 2       3        1110         7      3301       15766         1238
# 3       3        1110         7      3301       15766         1240
# 4       3        1110         7      3301       15766         1242
# 5       3        1110         7      3301       15766         1250
# 6       3        1110         7      3301       15766         1309
# 7       3        1110         7      3301       15766         3894
# 8       3        1110         7      3301       15766         4085
# 9       3        1110         7      3301       15766         5310
#
#    Venta_uni_hoy  Venta_hoy  Dev_uni_proxima  Dev_proxima  Demanda_uni_equil
# 0              3      25.14                0          0.0                  3
# ...

# %%
text_files
# Out:
# [<ZipInfo filename='cliente_tabla.csv' compress_type=deflate file_size=21254426 compress_size=6157007>,
#  <ZipInfo filename='sample_submission.csv' compress_type=deflate file_size=68881421 compress_size=15500911>,
#  <ZipInfo filename='test.csv' compress_type=deflate file_size=251114289 compress_size=92027641>,
#  <ZipInfo filename='train.csv' compress_type=deflate file_size=3199358223 compress_size=396347280>,
#  <ZipInfo filename='town_state.csv' compress_type=deflate file_size=29179 compress_size=6476>,
#  <ZipInfo filename='producto_tabla.csv' compress_type=deflate file_size=109549 compress_size=32575>]
